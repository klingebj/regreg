# %%
import regreg.api as rrimport numpy as np%load_ext rmagic

# %%
# %%R -o X,Ylibrary(lars)data(diabetes)X = diabetes$xY = diabetes$y

# %% [markdown]
# print X.shape, Y.shape

# %%
loss = rr.squared_error(X, Y)penalty_lagrange = rr.l1norm(10, lagrange=200)problem_lagrange = rr.simple_problem(loss, penalty_lagrange)coef_lagrange = problem.solve(tol=1.e-12)implied_bound = np.fabs(coef_lagrange).sum()

# %%
bound_constraint = rr.l1norm(10, bound=implied_bound)problem_lagrange = rr.simple_problem(loss, bound_constraint)coef_bound = problem.solve(tol=1.e-12)

# %%
np.linalg.norm(coef_bound - coef_lagrange) / np.linalg.norm(coef_lagrange)
# Out:
# 0.0

# %% [markdown]
# ## Path of solutions

# %%
import regreg.paths as RPlasso_path = RP.lasso.squared_error(X, -Y, lagrange_proportion=0.001)soln = lasso_path.main()RP.lasso?
# Out:
# 1.0 42.1163951424 3 0.045799859877 1 155.2476062170.932603346883 39.2778910685 3 0.0996827945067 2 159.1731840380.869749002618
#  36.630692669 3 0.146547422614 3 162.8341909560.81113083079
#  34.1619065817 3 0.187307876057 4 166.2484573840.756463327555
#  31.859508414 3 0.222757796765 5 169.4324793270.705480231072 29.712284177 3 0.253591783017 6 172.4020440740.657933224658
#  27.709775667 3 0.280409611864 7 175.1714701020.613590727341 25.8422295284 3 0.303734391757 8 177.7542460840.572236765935
#  24.1005497491 3 0.324021095804 9 180.162951610.533669923121 22.4762533578 3
# 0.341665507368 10 182.4093278040.497702356433
#  20.9614291069 4 0.3581074395 11 184.6571754960.464158883361
#  19.5486989405 4 0.373995954225 12 186.9829412390.432876128108 18.2311820591 4 0.387813842574 13 189.151786160.40370172586
#  17.002461406 4 0.399831970008 14 191.1744635520.376493580679 15.8565524125 4 0.410284591427 15 193.0607943810.351119173422
# ...

# %%
beta = np.array(soln['beta'].todense())soln['lagrange'].shapebeta[1].shapef1, ax1 = plt.subplots()[ax1.plot(soln['lagrange'],beta[i]) for i in range(1,11)]l1norm = np.fabs(beta[1:]).sum(0)f2, ax2= plt.subplots()[ax2.plot(l1norm,beta[i]) for i in range(1,11)];

# %%
# %%Rl = lars(X, Y)plot(l)#library(glmnet)#g = glmnet(X, Y)
